# %% [markdown]
# <a href="https://colab.research.google.com/github/lee7py/2021-py-bigdata/blob/main/my_ch09_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting and Visualization

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
print(PREVIOUS_MAX_ROWS)
pd.options.display.max_rows = 20

np.random.seed(12345)
np.set_printoptions(precision=4, suppress=True)
# Out:
# 60

# %%
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))

# %% [markdown]
# %matplotlib notebook

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 한글 지원

# %%
# 다음은 한번 실행하고 다시 '런타임 다시 시작' 후 다음 셀 실행
# 새로운 파일마다 이 셀은 실행 필요

# APT(Advanced Packaging Tool)로 폰트 설치 실행
# !apt -qq -y install fonts-nanum

import matplotlib as mpl
# 폰트 매니저의 메서드로 다시 폰트를 구성
# 폰트 구성 후 '다시 실행'해야 재설정된 폰트가 반영
mpl.font_manager._rebuild()
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160837 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 한글 폰트를 선명하도록 하는 파워명령어
# %config InlineBackend.figure_format = 'retina'

import matplotlib as mpl
import matplotlib.pyplot as plt

# 한글 폰트 지원
plt.rc('font', family='NanumBarunGothic') 
# 음수 부호 지원
mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.plot([-1,1], [-1,1], label='한글 지원')
plt.legend()

# %%
import matplotlib as mpl
sorted([f.name for f in mpl.font_manager.fontManager.ttflist])
# Out:
# ['DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'Humor Sans',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'Liberation Serif',
#  'Liberation Serif',
#  'Liberation Serif',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
# ...

# %% [markdown]
# ## A Brief matplotlib API Primer

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.arange(15, 30)
data
plt.plot(data);

# %% [markdown]
# ### 문제

# %%
import matplotlib.pyplot as plt
plt.plot([1, 1.5, 2, 2.5, 3]);

# %%
plt.plot([1, 2, 3, 4, 5], [1, 1.5, 2, 2.5, 3]);

# %%
plt.plot(np.arange(0, 5), [1, 1.5, 2, 2.5, 3])

# %%
plt.plot(np.arange(1, 6), [1, 1.5, 2, 2.5, 3])

# %% [markdown]
# * 한글 지원 방법

# %% [markdown]
# colab에서 한글지원

# %%
import matplotlib as mpl
sorted([f.name for f in mpl.font_manager.fontManager.ttflist])
# Out:
# ['DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'Humor Sans',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'Liberation Serif',
#  'Liberation Serif',
#  'Liberation Serif',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
# ...

# %% [markdown]
# ### Figures and Subplots

# %%
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(2, 2, 1)
#ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(2, 2, 1)
plt.plot(np.random.randn(50).cumsum(), 'k-.')
ax2 = fig.add_subplot(2, 2, 2)
plt.plot(np.random.randn(50).cumsum(), 'g-')
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'b:')
ax4 = fig.add_subplot(2, 2, 4)
plt.plot(np.random.randn(100).cumsum(), 'r--')

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
# ax3 = fig.add_subplot(2, 2, 3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'r--')
plt.title('제목')
# Out:
# Text(0.5, 1.0, '제목')

# %%
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
plt.plot(np.random.randn(50).cumsum(), '.m:')
ax3 = fig.add_subplot(2, 2, 3)
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.6)
ax3.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
plt.plot(np.random.randn(50).cumsum(), 'ms--')

# %%
plt.close('all')

# %% [markdown]
# * subplot()

# %%
ax1 = plt.subplot(2, 1, 1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('A tale of 2 subplots(제목)')
plt.ylabel('Damped oscillation')
print(ax1)

#ax2 = plt.subplot(2, 1, 2)
ax2 = plt.subplot(2, 1, 2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'rs-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig, axes = plt.subplots(2, 4, figsize=(8, 6))

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True, figsize=(8, 6))

# %%
fig

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Adjusting the spacing around subplots

# %% [markdown]
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %% [markdown]
# fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
# plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(8, 6))
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.1)
plt.subplots_adjust(wspace=0.02, hspace=.05)
#plt.subplots_adjust(wspace=None, hspace=None) #적정한 공간 비우기

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %% [markdown]
# ax.plot(x, y, 'g--')

# %% [markdown]
# ax.plot(x, y, linestyle='--', color='g')

# %%
plt.figure()

# %%
from numpy.random import randn
plt.plot(np.random.randn(30).cumsum(), 'yo--')

# %%
plt.plot(np.random.randn(30).cumsum(), color='m', linestyle='dashed', marker='o')

# %%
plt.plot(np.random.randn(30).cumsum(), 'ro:')

# %%
plt.close('all')

# %%
plt.plot?

# %%
plt.figure(figsize=(8, 6))
data = np.random.randn(30).cumsum()
plt.plot(data, 'c:', label='Default')
plt.plot(data, '>b-.', drawstyle='steps', label='steps-post')
plt.legend(loc='best')

# %%
fig, axes = plt.subplots(3, 2, sharex=True, sharey=True, figsize=(8, 6))

data = np.random.randn(10).cumsum()
axes[0][0].plot(data, 'oc:')
axes[0][0].set_title('oc:')

axes[0][1].plot(data, 'y--')
axes[0][1].plot(data, '^b-.', drawstyle='default', label='default')
axes[0][1].set_title('drawstyle=default')

axes[1][0].plot(data, 'y:')
axes[1][0].plot(data, '>b-.', drawstyle='steps-pre', label='steps-pre')
axes[1][0].set_title('drawstyle=steps-pre')

axes[1][1].plot(data, 'r-')
axes[1][1].plot(data, '>b-.', drawstyle='steps-mid', label='steps-mid')
axes[1][1].set_title('drawstyle=steps-mid')

axes[2][0].plot(data, 'm:')
axes[2][0].plot(data, '>b-.', drawstyle='steps-post', label='steps-post')
axes[2][0].set_title('drawstyle=steps-post')

axes[2][1].plot(data, 'g:')
axes[2][1].plot(data, '>b-.', drawstyle='steps', label='steps')
axes[2][1].set_title('drawstyle=steps')
# Out:
# Text(0.5, 1.0, 'drawstyle=steps')

# %% [markdown]
# ### Ticks, Labels, and Legends

# %% [markdown]
# #### Setting the title, axis labels, ticks, and ticklabels

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
plt.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
ax.plot(np.random.randn(1000).cumsum())

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 16.200000000000003, 'Stages')

# %%
import matplotlib as mpl

# 폰트 설정
#mpl.rc('font', family='NanumGothic')
mpl.rc('font', family='Malgun Gothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
ax.plot(np.random.randn(1000).cumsum())

ax.set_title('멧플롯리브 그림')
ax.set_xlabel('단계')
# Out:
# Text(0.5, 0, '단계')

# %% [markdown]
# props = {
#     'title': 'My first matplotlib plot',
#     'xlabel': 'Stages'
# }
# ax.set(**props)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
ax.plot(np.random.randn(1000).cumsum())

#ax.set_title('멧플롯리브 그림')
#ax.set_xlabel('단계')
props = { 'title': 'My first matplotlib plot', 'xlabel': 'Stages' }
ax.set(**props)
# Out:
# [Text(0.5, 1.0, 'My first matplotlib plot'), Text(0.5, 0, 'Stages')]

# %%
fig = plt.figure()
plt.xticks([0, 250, 500, 750, 1000], ['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')
plt.title('멧플롯리브 그림')
plt.xlabel('단계')
plt.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# ### 문제

# %%
fig = plt.figure();
fig.add_subplot(1, 2, 1);

# %%
fig = plt.figure();
fig.subplots(1, 2);

# %%
fig = plt.figure();
fig.add_subplot('121');

# %%
fig = plt.figure();
plt.subplot(1, 2, 1);

# %% [markdown]
# #### Adding legends

# %%
from numpy.random import randn
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'r', label='one')
ax.plot(randn(1000).cumsum(), 'g--', label='two')
ax.plot(randn(1000).cumsum(), 'b.', label='three')

ax.legend(loc='best')

# %%
ax.legend(loc='best')

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %% [markdown]
# ax.text(x, y, 'Hello world!',
#         family='monospace', fontsize=10)

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='yellow', shrink=1))

plt.ylim(-2, 2)
plt.show()

# %%
import pandas as pd
from datetime import datetime

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='g-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date)),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='cyan', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
spx[:10]
# Out:
# 1990-02-01    328.79
# 1990-02-02    330.92
# 1990-02-05    331.85
# 1990-02-06    329.66
# 1990-02-07    333.75
# 1990-02-08    332.96
# 1990-02-09    333.62
# 1990-02-12    330.08
# 1990-02-13    331.02
# 1990-02-14    332.01
# Name: SPX, dtype: float64

# %%
ax.set_title('Important dates in the 2008–2009 financial crisis')

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
# circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
# pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
#                    color='g', alpha=0.5)
#
# ax.add_patch(rect)
# ax.add_patch(circ)
# ax.add_patch(pgon)

# %%
fig = plt.figure(figsize=(12, 6)); ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ### Saving Plots to File

# %% [markdown]
# plt.savefig('figpath.svg')

# %% [markdown]
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# from io import BytesIO
# buffer = BytesIO()
# plt.savefig(buffer)
# plot_data = buffer.getvalue()

# %% [markdown]
# ### matplotlib Configuration

# %% [markdown]
# plt.rc('figure', figsize=(10, 10))

# %% [markdown]
# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size'   : 'small'}
# plt.rc('font', **font_options)

# %% [markdown]
# * close()

# %%
plt.close('all')

# %%
import matplotlib.pyplot as plt

fig1 = plt.figure() # create first figure
plt.plot([0, 1], [0, 1])

fig2 = plt.figure() # create second figure
plt.plot([0, 1], [0, 1])

#plt.close(fig1) # close first figure although second one is active
plt.close(fig2) # close first figure although second one is active

# %%
plt.close(fig1) # close first figure although second one is active
plt.close(fig2) # close first figure although second one is active

# %% [markdown]
# ## Plotting with pandas and seaborn

# %% [markdown]
# ### Line Plots

# %%
import pandas as pd
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df
df.plot();

# %%
df.plot()

# %% [markdown]
# ### Bar Plots

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='b', alpha=0.7)

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.370670  0.602792  0.229159  0.486744
# two    0.420082  0.571653  0.049024  0.880592
# three  0.814568  0.277160  0.880316  0.431326
# four   0.374020  0.899420  0.460304  0.100843
# five   0.433270  0.125107  0.494675  0.961825
# six    0.601648  0.478576  0.205690  0.560547

# %%
df.plot.bar(ylim=[0, 1.2])

# %%
df.plot.bar(ylim=[0, 3.5], stacked=True)

# %%
plt.figure()

# %%
df.plot.barh(stacked=True, alpha=0.8)

# %%
plt.close('all')

# %%
#코랩에서 사용
# !ls
# Out:
# sample_data  tips.csv

# %%
#코랩에서 파일업로드 사용
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-19f50213-12b2-4dd8-8c9b-096d52fc8fac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19f50213-12b2-4dd8-8c9b-096d52fc8fac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv
# ...

# %%
#코랩에서 사용
# !ls
# Out:
# sample_data  tips.csv

# %%
#tips = pd.read_csv('examples/tips.csv')
#코랩에서 사용
tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   smoker      244 non-null    object
#  3   day         244 non-null    object
#  4   time        244 non-null    object
#  5   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.6+ KB

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
# Not many 1- and 6-person parties
party_counts = party_counts.loc[:, 2:5]
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
# Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()

# %%
#tips = pd.read_csv('examples/tips.csv')
tips = pd.read_csv('tips.csv')
party_counts = pd.crosstab(tips['day'], tips['size'])
# Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts.plot.bar()

# %%
plt.close('all')

# %%
import seaborn as sns
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
import seaborn as sns
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
plt.close('all')

# %%
#sns.set(style="darkgrid") #whitegrid, darkgrid
sns.set(style="whitegrid") #whitegrid, darkgrid
sns.barplot(x='tip_pct', y='day', hue='smoker', data=tips, orient='h')
#sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h');

# %%
sns.set(style="whitegrid")
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')

# %%
plt.close('all')

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ### Histograms and Density Plots

# %%
plt.figure()

# %%
len(tips)
# Out:
# 244

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
plt.figure()

# %%
tips['tip_pct'].plot.density()

# %%
plt.figure()
plt.rcParams['figure.figsize'] = [8, 6]

# %%
comp1 = np.random.normal(0, 2, size=200)
comp2 = np.random.normal(10, 1, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='r')

# %% [markdown]
# ### Scatter or Point Plots

# %%
# !ls
# Out:
# sample_data  tips.csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-94e11056-7967-47dd-89e5-bffadd276363" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94e11056-7967-47dd-89e5-bffadd276363">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving macrodata.csv to macrodata.csv
# ...

# %%
#macro = pd.read_csv('examples/macrodata.csv')
macro = pd.read_csv('macrodata.csv')
macro.head()
# Out:
#      year  quarter   realgdp  realcons  ...  unemp      pop  infl  realint
# 0  1959.0      1.0  2710.349    1707.4  ...    5.8  177.146  0.00     0.00
# 1  1959.0      2.0  2778.801    1733.7  ...    5.1  177.830  2.34     0.74
# 2  1959.0      3.0  2775.488    1751.8  ...    5.3  178.657  2.74     1.09
# 3  1959.0      4.0  2785.204    1753.7  ...    5.6  179.386  0.27     4.06
# 4  1960.0      1.0  2847.699    1770.5  ...    5.2  180.007  2.31     1.19
#
# [5 rows x 14 columns]

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data.head()
# Out:
#      cpi     m1  tbilrate  unemp
# 0  28.98  139.7      2.82    5.8
# 1  29.15  141.7      3.08    5.1
# 2  29.35  140.5      3.82    5.3
# 3  29.37  140.0      4.33    5.6
# 4  29.54  139.6      3.50    5.2

# %%
data.diff()
# Out:
#        cpi     m1  tbilrate  unemp
# 0      NaN    NaN       NaN    NaN
# 1    0.170    2.0      0.26   -0.7
# 2    0.200   -1.2      0.74    0.2
# 3    0.020   -0.5      0.51    0.3
# 4    0.170   -0.4     -0.83   -0.4
# ..     ...    ...       ...    ...
# 198 -1.721   65.4     -0.57    0.6
# 199 -4.715  101.8     -1.05    0.9
# 200  0.497   16.3      0.10    1.2
# 201  1.798   60.8     -0.04    1.1
# 202  1.916   20.3     -0.06    0.4
#
# [203 rows x 4 columns]

# %%
np.log(data).diff().dropna()
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# ..        ...       ...       ...       ...
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [202 rows x 4 columns]

# %%
trans_data = np.log(data).diff().dropna()
trans_data[-5:]
trans_data.tail()
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.figure()

# %%
sns.regplot('m1', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.7})

# %% [markdown]
# ### Facet Grids and Categorical Data

# %%
tips[tips.tip_pct >= 0.5] # 특잇값
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 172        7.25  5.15    Yes  Sun  Dinner     2  2.452381
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.714286

# %%
sns.catplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips)

# %%
#factorplot
sns.catplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])

# %%
sns.catplot(x='day', y='tip_pct', row='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])

# %%
sns.catplot(x='tip_pct', y='day', kind='box', data=tips)

# %%
sns.catplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 1])

# %%
sns.catplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 0.4])

# %% [markdown]
# ## Other Python Visualization Tools

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * bokeh

# %%
# !pip show bokeh
# Out:
# Name: bokeh
# Version: 2.3.3
# Summary: Interactive plots and applications in the browser from Python
# Home-page: http://github.com/bokeh/bokeh
# Author: Bokeh Team
# Author-email: info@bokeh.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: packaging, python-dateutil, tornado, numpy, PyYAML, Jinja2, typing-extensions, pillow
# Required-by: panel

# %%
# !pip install bokeh

# %%
# colab에서 bokeh 지원
from bokeh.io import output_notebook
output_notebook()

# %%
from bokeh.plotting import figure, show

# from bokeh.plotting import output_file
# 출력파일 지정, 없으면 소스파일과 동일한 html 파일로 생성
# output_file("line.html")

p = figure()
# p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5])
# p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)

show(p)
# Out:
#   <div class="bk-root" id="3afd9d04-0efd-4408-b91b-80c7dab269aa" data-root-id="1142"></div>

# %%
from bokeh.plotting import figure, show, output_file

p = figure(plot_width=400, plot_height=400)
p.quad(top=[2, 3, 4], bottom=[1, 2, 3], left=[1, 2, 3], right=[1.2, 2.5, 3.7], color="#B3DE69")

show(p)
output_file('rectangles.html')
# Out:
#   <div class="bk-root" id="ac2e6f52-26c7-481c-a443-acb98c54cfc4" data-root-id="1255"></div>

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
